# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Collection and Preprocessing

# %%
stores=pd.read_csv("E:/Data Science Project/Final Project/stores_data_set.csv")
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
sales=pd.read_csv("E:/Data Science Project/Final Project/sales_data_set.csv")
sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
features=pd.read_csv("E:/Data Science Project/Final Project/Features_data_set.csv")
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
merged_df=pd.merge(stores,sales,on=["Store"],how="left")
merged_df
# Out:
#         Store Type    Size  Dept        Date  Weekly_Sales  IsHoliday
# 0           1    A  151315     1  05/02/2010      24924.50      False
# 1           1    A  151315     1  12/02/2010      46039.49       True
# 2           1    A  151315     1  19/02/2010      41595.55      False
# 3           1    A  151315     1  26/02/2010      19403.54      False
# 4           1    A  151315     1  05/03/2010      21827.90      False
# ...       ...  ...     ...   ...         ...           ...        ...
# 421565     45    B  118221    98  28/09/2012        508.37      False
# 421566     45    B  118221    98  05/10/2012        628.10      False
# 421567     45    B  118221    98  12/10/2012       1061.02      False
# 421568     45    B  118221    98  19/10/2012        760.01      False
# 421569     45    B  118221    98  26/10/2012       1076.80      False
#
# [421570 rows x 7 columns]

# %%
df= pd.merge(merged_df,features,on=["Store","Date"])
df
# Out:
#         Store Type    Size  Dept        Date  Weekly_Sales  IsHoliday_x  \
# 0           1    A  151315     1  05/02/2010      24924.50        False
# 1           1    A  151315     1  12/02/2010      46039.49         True
# 2           1    A  151315     1  19/02/2010      41595.55        False
# 3           1    A  151315     1  26/02/2010      19403.54        False
# 4           1    A  151315     1  05/03/2010      21827.90        False
# ...       ...  ...     ...   ...         ...           ...          ...
# 421565     45    B  118221    98  28/09/2012        508.37        False
# 421566     45    B  118221    98  05/10/2012        628.10        False
# 421567     45    B  118221    98  12/10/2012       1061.02        False
# 421568     45    B  118221    98  19/10/2012        760.01        False
# 421569     45    B  118221    98  26/10/2012       1076.80        False
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# ...

# %% [markdown]
# checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# checking for null values

# %%
df.isnull().sum()
# Out:
# Store                0
# Type                 0
# Size                 0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday_x          0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday_y          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Store', 'Type', 'Size', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday_x',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday_y'],
#       dtype='object')

# %%
df[["MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"]]=df[["MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"]].fillna(0)

# %%
df.isnull().sum()
# Out:
# Store           0
# Type            0
# Size            0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday_x     0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday_y     0
# dtype: int64

# %%
df
# Out:
#         Store Type    Size  Dept        Date  Weekly_Sales  IsHoliday_x  \
# 0           1    A  151315     1  05/02/2010      24924.50        False
# 1           1    A  151315     1  12/02/2010      46039.49         True
# 2           1    A  151315     1  19/02/2010      41595.55        False
# 3           1    A  151315     1  26/02/2010      19403.54        False
# 4           1    A  151315     1  05/03/2010      21827.90        False
# ...       ...  ...     ...   ...         ...           ...          ...
# 421565     45    B  118221    98  28/09/2012        508.37        False
# 421566     45    B  118221    98  05/10/2012        628.10        False
# 421567     45    B  118221    98  12/10/2012       1061.02        False
# 421568     45    B  118221    98  19/10/2012        760.01        False
# 421569     45    B  118221    98  26/10/2012       1076.80        False
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Type          421570 non-null  object
#  2   Size          421570 non-null  int64
#  3   Dept          421570 non-null  int64
#  4   Date          421570 non-null  object
#  5   Weekly_Sales  421570 non-null  float64
#  6   IsHoliday_x   421570 non-null  bool
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     421570 non-null  float64
#  10  MarkDown2     421570 non-null  float64
#  11  MarkDown3     421570 non-null  float64
#  12  MarkDown4     421570 non-null  float64
#  13  MarkDown5     421570 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
#  16  IsHoliday_y   421570 non-null  bool
# ...

# %%
#converting the date column to datetime format
df["Date"]=pd.to_datetime(df["Date"],format="%d/%m/%Y")

# %%
df["Day"] = df["Date"].dt.day
df["Week"]=df["Date"].dt.isocalendar().week
df["Month"] = df["Date"].dt.month
df["Year"] = df["Date"].dt.year

# %%
df["IsHoliday_Same"] = df["IsHoliday_x"] == df["IsHoliday_y"]

# %%
df["IsHoliday_Same"].value_counts()
# Out:
# IsHoliday_Same
# True    421570
# Name: count, dtype: int64

# %%
df.drop(["IsHoliday_x","IsHoliday_Same"],axis=1,inplace=True)

# %%
df.rename(columns={"IsHoliday_y":"IsHoliday"},inplace=True)
df
# Out:
#         Store Type    Size  Dept       Date  Weekly_Sales  Temperature  \
# 0           1    A  151315     1 2010-02-05      24924.50        42.31
# 1           1    A  151315     1 2010-02-12      46039.49        38.51
# 2           1    A  151315     1 2010-02-19      41595.55        39.93
# 3           1    A  151315     1 2010-02-26      19403.54        46.63
# 4           1    A  151315     1 2010-03-05      21827.90        46.50
# ...       ...  ...     ...   ...        ...           ...          ...
# 421565     45    B  118221    98 2012-09-28        508.37        64.88
# 421566     45    B  118221    98 2012-10-05        628.10        64.89
# 421567     45    B  118221    98 2012-10-12       1061.02        54.47
# 421568     45    B  118221    98 2012-10-19        760.01        56.47
# 421569     45    B  118221    98 2012-10-26       1076.80        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df1= df.copy()
df1
# Out:
#         Store Type    Size  Dept       Date  Weekly_Sales  Temperature  \
# 0           1    A  151315     1 2010-02-05      24924.50        42.31
# 1           1    A  151315     1 2010-02-12      46039.49        38.51
# 2           1    A  151315     1 2010-02-19      41595.55        39.93
# 3           1    A  151315     1 2010-02-26      19403.54        46.63
# 4           1    A  151315     1 2010-03-05      21827.90        46.50
# ...       ...  ...     ...   ...        ...           ...          ...
# 421565     45    B  118221    98 2012-09-28        508.37        64.88
# 421566     45    B  118221    98 2012-10-05        628.10        64.89
# 421567     45    B  118221    98 2012-10-12       1061.02        54.47
# 421568     45    B  118221    98 2012-10-19        760.01        56.47
# 421569     45    B  118221    98 2012-10-26       1076.80        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Statistical Analysis

# %%
df1.describe().T
# Out:
#                  count                           mean                  min  \
# Store         421570.0                      22.200546                  1.0
# Size          421570.0                  136727.915739              34875.0
# Dept          421570.0                      44.260317                  1.0
# Date            421570  2011-06-18 08:30:31.963375104  2010-02-05 00:00:00
# Weekly_Sales  421570.0                   15981.258123             -4988.94
# Temperature   421570.0                      60.090059                -2.06
# Fuel_Price    421570.0                       3.361027                2.472
# MarkDown1     421570.0                    2590.074819                  0.0
# MarkDown2     421570.0                     879.974298              -265.76
# MarkDown3     421570.0                     468.087665                -29.1
# MarkDown4     421570.0                    1083.132268                  0.0
# ...

# %% [markdown]
# Sales trend analysis

# %%
Total_weekly_sales=df1.groupby("Date")["Weekly_Sales"].sum().reset_index()
Total_weekly_sales
# Out:
#           Date  Weekly_Sales
# 0   2010-02-05   49750740.50
# 1   2010-02-12   48336677.63
# 2   2010-02-19   48276993.78
# 3   2010-02-26   43968571.13
# 4   2010-03-05   46871470.30
# ..         ...           ...
# 138 2012-09-28   43734899.40
# 139 2012-10-05   47566639.31
# 140 2012-10-12   46128514.25
# 141 2012-10-19   45122410.57
# 142 2012-10-26   45544116.29
#
# [143 rows x 2 columns]

# %%
#plot the total weekly sales
plt.figure(figsize=(10,6))
plt.plot(Total_weekly_sales["Date"],Total_weekly_sales["Weekly_Sales"],color="green",label="Total Weekly Sales")
plt.xlabel("Date")
plt.ylabel("Weekly_Sales")
plt.title("Total Weekly Sales")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Total Sales by store type and size

# %%
Average_sales_by_type=df1.groupby("Type")["Weekly_Sales"].mean().reset_index()
Average_sales_by_type
# Out:
#   Type  Weekly_Sales
# 0    A  20099.568043
# 1    B  12237.075977
# 2    C   9519.532538

# %%
plt.figure(figsize=(5,5))
plt.bar(Average_sales_by_type["Type"],Average_sales_by_type["Weekly_Sales"],color="blue",label="Average Sales by Type")
plt.xlabel("Type")
plt.ylabel("Average Weekly Sales")
plt.title("Average Sales by Type")
plt.show()

# %%
Average_sales_by_size=df1.groupby("Size")["Weekly_Sales"].mean().reset_index()
Average_sales_by_size.head()
# Out:
#     Size  Weekly_Sales
# 0  34875   5053.415813
# 1  37392   6373.033983
# 2  39690   8262.936295
# 3  39910   8297.715353
# 4  41062  13415.114118

# %%
plt.figure(figsize=(10,6))
plt.scatter(Average_sales_by_size["Size"],Average_sales_by_size["Weekly_Sales"],color="red",label="Average Sales by Store Size")
plt.xlabel("Store Size")
plt.ylabel("Average Weekly Sales")
plt.title("Average Sales by Store Size")
plt.legend()
plt.show()

# %% [markdown]
# Holiday Sales analysis

# %%
Holiday_sales=df1.groupby("IsHoliday")["Weekly_Sales"].mean().reset_index()
Holiday_sales
# Out:
#    IsHoliday  Weekly_Sales
# 0      False  15901.445069
# 1       True  17035.823187

# %%
plt.figure(figsize=(5,5))
plt.bar(Holiday_sales["IsHoliday"],Holiday_sales["Weekly_Sales"],color="purple")
plt.xticks(ticks=[0,1],labels=["False","True"])
plt.xlabel("Holiday")
plt.ylabel("Weekly_Sales")
plt.title("Average Sales by Holiday")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df1.groupby("Month")["Weekly_Sales"].mean()
# Out:
# Month
# 1     14126.075111
# 2     16008.779217
# 3     15416.657597
# 4     15650.338357
# 5     15776.337202
# 6     16326.137002
# 7     15861.419650
# 8     16062.516933
# 9     15095.886154
# 10    15243.855576
# 11    17491.031424
# 12    19355.702141
# Name: Weekly_Sales, dtype: float64

# %%
df1.groupby("Year")["Weekly_Sales"].mean()
# Out:
# Year
# 2010    16270.275737
# 2011    15954.070675
# 2012    15694.948597
# Name: Weekly_Sales, dtype: float64

# %%
monthly_sales=pd.pivot_table(data=df,index="Month",values="Weekly_Sales",columns="Year")
monthly_sales.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
weekly_sales=pd.pivot_table(data=df,index="Week",values="Weekly_Sales",columns="Year")
weekly_sales.plot()
# Out:
# <Axes: xlabel='Week'>

# %% [markdown]
# Visualizing the Skewness and Outliers

# %%
# function for box plot, hist plot, violin plot
def plot(df,column):
    plt.figure(figsize=(20,5))

    plt.subplot(1,3,1)
    sns.histplot(data= df1,x=column,kde=True,bins=30,color='salmon')
    plt.title(f'Distribution Plot for {column}')
    plt.show

    plt.subplot(1,3,2)
    sns.boxplot(data= df1,x=column,color='green')
    plt.title(f'Box Plot for {column}')
    plt.show

    plt.subplot(1,3,3)
    sns.violinplot(data=df1,x=column,color='indigo')
    plt.title(f'Violin Plot for {column}')
    plt.show

# %%
df1.columns
# Out:
# Index(['Store', 'Type', 'Size', 'Dept', 'Date', 'Weekly_Sales', 'Temperature',
#        'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
#        'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday', 'Day', 'Week', 'Month',
#        'Year'],
#       dtype='object')

# %%
# plotting to check skew
for col in ['Store', 'Type', 'Size', 'Dept', 'Date', 'Weekly_Sales', 'Temperature',
       'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
       'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday', 'Day', 'Week', 'Month',
       'Year']:
    plot(df1,col)

# %% [markdown]
# Correlation

# %%
numerical_columns=["Store","Size","Dept","Weekly_Sales","Temperature","Fuel_Price","MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5","CPI","Unemployment","Day","Week","Month","Year"]
corr=df1[numerical_columns].corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,fmt='.2f',cbar=False,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Converting the categorical data into numerical data

# %%
df1["Type"]=df1["Type"].replace({"A":1,"B":2,"C":3})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21428\2308916765.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["Type"]=df1["Type"].replace({"A":1,"B":2,"C":3})

# %%
df1["IsHoliday"].unique()
# Out:
# array([False,  True])

# %%
df1["IsHoliday"].value_counts()
# Out:
# IsHoliday
# False    391909
# True      29661
# Name: count, dtype: int64

# %%
df1["IsHoliday"]=df1["IsHoliday"].apply(lambda x:1 if x==1 else 0)

# %%
df1.drop("Date",axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Type          421570 non-null  int64
#  2   Size          421570 non-null  int64
#  3   Dept          421570 non-null  int64
#  4   Weekly_Sales  421570 non-null  float64
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     421570 non-null  float64
#  8   MarkDown2     421570 non-null  float64
#  9   MarkDown3     421570 non-null  float64
#  10  MarkDown4     421570 non-null  float64
#  11  MarkDown5     421570 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  IsHoliday     421570 non-null  int64
#  15  Day           421570 non-null  int32
#  16  Week          421570 non-null  UInt32
# ...

# %%
df1["Day"]=df1["Day"].astype("int64")
df1["Week"]=df1["Week"].astype("int64")
df1["Month"]=df1["Month"].astype("int64")
df1["Year"]=df1["Year"].astype("int64")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Type          421570 non-null  int64
#  2   Size          421570 non-null  int64
#  3   Dept          421570 non-null  int64
#  4   Weekly_Sales  421570 non-null  float64
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     421570 non-null  float64
#  8   MarkDown2     421570 non-null  float64
#  9   MarkDown3     421570 non-null  float64
#  10  MarkDown4     421570 non-null  float64
#  11  MarkDown5     421570 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  IsHoliday     421570 non-null  int64
#  15  Day           421570 non-null  int64
#  16  Week          421570 non-null  int64
# ...

# %% [markdown]
# Creating Lag Features for Weekly Sales

# %%
df1["Weekly_Sales_Lag1"]=df1["Weekly_Sales"].shift(1)

# %%
df1['Weekly_Sales_Lag1'] = df1['Weekly_Sales_Lag1'].fillna(0)

# %%
df1
# Out:
#         Store  Type    Size  Dept  Weekly_Sales  Temperature  Fuel_Price  \
# 0           1     1  151315     1      24924.50        42.31       2.572
# 1           1     1  151315     1      46039.49        38.51       2.548
# 2           1     1  151315     1      41595.55        39.93       2.514
# 3           1     1  151315     1      19403.54        46.63       2.561
# 4           1     1  151315     1      21827.90        46.50       2.625
# ...       ...   ...     ...   ...           ...          ...         ...
# 421565     45     2  118221    98        508.37        64.88       3.997
# 421566     45     2  118221    98        628.10        64.89       3.985
# 421567     45     2  118221    98       1061.02        54.47       4.000
# 421568     45     2  118221    98        760.01        56.47       3.969
# 421569     45     2  118221    98       1076.80        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# ...

# %% [markdown]
# Holiday Interaction Features

# %% [markdown]
#  Markdown and Holiday Interactions

# %%
df1["Total_Markdowns"] = df1["MarkDown1"] + df1["MarkDown2"] + df1["MarkDown3"] + df1["MarkDown4"] + df1["MarkDown5"]
df1["Markdown_Holiday_Impact"] = df1["Total_Markdowns"] * df1["IsHoliday"]

# %%
df1.drop("Total_Markdowns", axis=1, inplace=True)

# %%
df1.to_csv('final_project.csv',index=False)
